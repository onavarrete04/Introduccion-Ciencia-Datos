# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importar datos

df1 = pd.read_csv("Turismo Recaudo Contribución Parafiscal.csv") 

# ver datos

df1.head()
# Out:
#                                      CLASE APORTANTE           ANO-2014  \
# 0                     Hoteles y Centros Vacacionales   $ 8.258.014.655
# 1  Viviendas Turísticas u otro tipo de hospedaje ...     $ 253.062.203
# 2                                 Agencias de Viajes   $ 2.370.773.024
# 3                Oficina de Representación Turística     $ 195.130.444
# 4                                  Deportes naúticos       $ 7.606.910
#
#             ANO-2015            ANO-2016            ANO-2017  \
# 0   $ 9.370.587.368    $ 10.865.531.432    $ 11.700.296.314
# 1     $ 306.329.082       $ 368.429.386       $ 426.940.968
# 2   $ 2.605.481.965     $ 2.976.564.291     $ 3.211.374.588
# 3     $ 199.788.688       $ 196.877.323       $ 181.569.000
# 4       $ 8.940.064         $ 7.729.342        $ 12.520.000
#
#              ANO-2018            ANO-2019           ANO-2020  \
# 0   $ 13.717.612.224    $ 15.053.610.576    $ 8.780.051.895
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CLASE APORTANTE  28 non-null     object
#  1   ANO-2014         28 non-null     object
#  2   ANO-2015         28 non-null     object
#  3   ANO-2016         28 non-null     object
#  4   ANO-2017         28 non-null     object
#  5   ANO-2018         28 non-null     object
#  6   ANO-2019         28 non-null     object
#  7   ANO-2020         28 non-null     object
#  8   ANO-2021         28 non-null     object
# dtypes: object(9)
# memory usage: 2.1+ KB

# %%
# remplazar signo $

df1["ANO-2014"] = df1["ANO-2014"].str.replace("$","",regex=True)

# %%
df1["ANO-2014"]
# Out:
# 0        8.258.014.655
# 1          253.062.203
# 2        2.370.773.024
# 3          195.130.444
# 4            7.606.910
# 5          567.514.503
# 6           62.924.327
# 7            1.184.218
# 8          130.782.894
# 9        2.576.006.431
# 10           1.690.000
# 11          17.469.784
# 12         210.542.208
# 13         390.281.711
# 14      19.677.188.617
# 15         990.519.699
# 16         200.456.735
# 17          29.661.773
# 18          42.972.140
# 19          89.398.633
# 20          36.623.368
# 21       1.211.173.896
# 22              40.087
# 23                 -
# 24              51.975
# 25                 -
# 26                 -
# 27          13.488.011
# Name: ANO-2014, dtype: object

# %%
df1 = df1.replace("\$","", regex=True)

# %%
df1 = df1.replace("\.","", regex=True)

# %%
df1.head()
# Out:
#                                      CLASE APORTANTE       ANO-2014  \
# 0                     Hoteles y Centros Vacacionales    8258014655
# 1  Viviendas Turísticas u otro tipo de hospedaje ...     253062203
# 2                                 Agencias de Viajes    2370773024
# 3                Oficina de Representación Turística     195130444
# 4                                  Deportes naúticos       7606910
#
#         ANO-2015        ANO-2016        ANO-2017        ANO-2018  \
# 0    9370587368     10865531432     11700296314     13717612224
# 1     306329082       368429386       426940968       662194250
# 2    2605481965      2976564291      3211374588      3881301106
# 3     199788688       196877323       181569000       208531000
# 4       8940064         7729342        12520000        19088000
#
#          ANO-2019       ANO-2020        ANO-2021
# 0    15053610576     8780051895     10179038000
# 1      796846000      559716000       864590000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CLASE APORTANTE  28 non-null     object
#  1   ANO-2014         28 non-null     object
#  2   ANO-2015         28 non-null     object
#  3   ANO-2016         28 non-null     object
#  4   ANO-2017         28 non-null     object
#  5   ANO-2018         28 non-null     object
#  6   ANO-2019         28 non-null     object
#  7   ANO-2020         28 non-null     object
#  8   ANO-2021         28 non-null     object
# dtypes: object(9)
# memory usage: 2.1+ KB

# %%
df1.replace("  -   ","NaN")
df1.head(40)
# Out:
#                                       CLASE APORTANTE        ANO-2014  \
# 0                      Hoteles y Centros Vacacionales     8258014655
# 1   Viviendas Turísticas u otro tipo de hospedaje ...      253062203
# 2                                  Agencias de Viajes     2370773024
# 3                 Oficina de Representación Turística      195130444
# 4                                   Deportes naúticos        7606910
# 5         Operadores Congresos, ferias y convenciones      567514503
# 6                           Arrendadores de Vehiculos       62924327
# 7                              Usuarios zonas francas        1184218
# 8   Comercializadora Proyecto Tiempo Compartido y ...      130782894
# 9                     Bares y restaurantes turísticos     2576006431
# 10                 Centros terapéuticos o balnearios         1690000
# 11                    Servicios turísticos prepagados       17469784
# 12                                  Parques temáticos      210542208
# ...

# %%
df1 = df1.replace("-","0",regex=True)
df1.head(40)

# Cambiando los espacios vácios a numero 0
# Out:
#                                       CLASE APORTANTE        ANO-2014  \
# 0                      Hoteles y Centros Vacacionales     8258014655
# 1   Viviendas Turísticas u otro tipo de hospedaje ...      253062203
# 2                                  Agencias de Viajes     2370773024
# 3                 Oficina de Representación Turística      195130444
# 4                                   Deportes naúticos        7606910
# 5         Operadores Congresos, ferias y convenciones      567514503
# 6                           Arrendadores de Vehiculos       62924327
# 7                              Usuarios zonas francas        1184218
# 8   Comercializadora Proyecto Tiempo Compartido y ...      130782894
# 9                     Bares y restaurantes turísticos     2576006431
# 10                 Centros terapéuticos o balnearios         1690000
# 11                    Servicios turísticos prepagados       17469784
# 12                                  Parques temáticos      210542208
# ...

# %%
 DATA = df1

# %%
df1["ANO-2016"]=df1["ANO-2016"].astype(int)
df1["ANO-2017"]=df1["ANO-2017"].astype(int)
df1["ANO-2018"]=df1["ANO-2018"].astype(int)
df1["ANO-2019"]=df1["ANO-2019"].astype(int)
df1["ANO-2020"]=df1["ANO-2020"].astype(int)
df1["ANO-2021"]=df1["ANO-2021"].astype(int)

# comprobando

# %%
df1.info()

# comprobación cambio de elementos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CLASE APORTANTE  28 non-null     object
#  1   ANO-2014         28 non-null     object
#  2   ANO-2015         28 non-null     object
#  3   ANO-2016         28 non-null     int64
#  4   ANO-2017         28 non-null     int64
#  5   ANO-2018         28 non-null     int64
#  6   ANO-2019         28 non-null     int64
#  7   ANO-2020         28 non-null     int64
#  8   ANO-2021         28 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 2.1+ KB

# %%
#

a =df1.groupby(["ANO-2014","ANO-2015"])["CLASE APORTANTE"].value_counts()
a
# Out:
# ANO-2014        ANO-2015        CLASE APORTANTE
#   0               0             Multinivel Servicios Turisticos                                 1
#                                 Operadores de plataformas electrónicas o digitales              1
#                                 Transporte Aéreo No Regular                                     1
#   1184218         910528        Usuarios zonas francas                                          1
#   1211173896      1299123408    Establecimientos en terminales                                  1
#   130782894       135474118     Comercializadora Proyecto Tiempo Compartido y Multipropiedad    1
#   13488011        75313755      Partidas no identificadas                                       1
#   1690000         1725000       Centros terapéuticos o balnearios                               1
#   17469784        17618608      Servicios turísticos prepagados                                 1
# ...

# %%
categorica_variables = ["CLASE APORTANTE",]
cuantitativa_variables = ["ANO-2014","ANO-2015","ANO-2016","ANO-2017","ANO-2018","ANO-2019","ANO-2020","ANO-2021"]

# %%
df1.head()
# Out:
#                                      CLASE APORTANTE       ANO-2014  \
# 0                     Hoteles y Centros Vacacionales    8258014655
# 1  Viviendas Turísticas u otro tipo de hospedaje ...     253062203
# 2                                 Agencias de Viajes    2370773024
# 3                Oficina de Representación Turística     195130444
# 4                                  Deportes naúticos       7606910
#
#         ANO-2015     ANO-2016     ANO-2017     ANO-2018     ANO-2019  \
# 0    9370587368   10865531432  11700296314  13717612224  15053610576
# 1     306329082     368429386    426940968    662194250    796846000
# 2    2605481965    2976564291   3211374588   3881301106   4248724357
# 3     199788688     196877323    181569000    208531000    237586898
# 4       8940064       7729342     12520000     19088000     20660000
#
#      ANO-2020     ANO-2021
# 0  8780051895  10179038000
# 1   559716000    864590000
# 2  2362685045   2228914000
# 3   132111083    248309000
# ...

# %%
df2 = pd.melt(df1, id_vars='CLASE APORTANTE', value_vars=['ANO-2014', 'ANO-2015', 'ANO-2016',
                                                          'ANO-2017', 'ANO-2018', 'ANO-2019',
                                                          'ANO-2020', 'ANO-2021'])

# %%
df2
# Out:
#                                        CLASE APORTANTE  variable  \
# 0                       Hoteles y Centros Vacacionales  ANO-2014
# 1    Viviendas Turísticas u otro tipo de hospedaje ...  ANO-2014
# 2                                   Agencias de Viajes  ANO-2014
# 3                  Oficina de Representación Turística  ANO-2014
# 4                                    Deportes naúticos  ANO-2014
# ..                                                 ...       ...
# 219                    Multinivel Servicios Turisticos  ANO-2021
# 220                                   Guias de Turismo  ANO-2021
# 221  Operadores de plataformas electrónicas o digit...  ANO-2021
# 222                        Transporte Aéreo No Regular  ANO-2021
# 223                          Partidas no identificadas  ANO-2021
#
#              value
# 0      8258014655
# 1       253062203
# 2      2370773024
# 3       195130444
# 4         7606910
# ..             ...
# 219        6011000
# 220        3365000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CLASE APORTANTE  224 non-null    object
#  1   variable         224 non-null    object
#  2   value            224 non-null    object
# dtypes: object(3)
# memory usage: 5.4+ KB

# %%
df2["value"]=df2["value"].astype(int)

# %%
sns.histplot(data=df2,y="CLASE APORTANTE", x="value",hue="variable")
# Out:
# <AxesSubplot:xlabel='value', ylabel='CLASE APORTANTE'>

# %%
_ = sns.FacetGrid(df2, col="CLASE APORTANTE").map(plt.scatter, "variable","CLASE APORTANTE","value",alpha=0.4).add_legend()

# %%
a =  df2.loc[(df2["CLASE APORTANTE"] == "Hoteles y Centros Vacacionales"),:]
plt.figure(figsize=(12,4))
sns.histplot(y=a["CLASE APORTANTE"],x=(a["value"]),hue=a.variable)
# Out:
# <AxesSubplot:xlabel='value', ylabel='CLASE APORTANTE'>

# %%
a1 = df1.iloc[:,0:3]
a1
# Out:
#                                       CLASE APORTANTE        ANO-2014  \
# 0                      Hoteles y Centros Vacacionales     8258014655
# 1   Viviendas Turísticas u otro tipo de hospedaje ...      253062203
# 2                                  Agencias de Viajes     2370773024
# 3                 Oficina de Representación Turística      195130444
# 4                                   Deportes naúticos        7606910
# 5         Operadores Congresos, ferias y convenciones      567514503
# 6                           Arrendadores de Vehiculos       62924327
# 7                              Usuarios zonas francas        1184218
# 8   Comercializadora Proyecto Tiempo Compartido y ...      130782894
# 9                     Bares y restaurantes turísticos     2576006431
# 10                 Centros terapéuticos o balnearios         1690000
# 11                    Servicios turísticos prepagados       17469784
# 12                                  Parques temáticos      210542208
# ...

# %%
a2 = pd.melt(a1, id_vars='CLASE APORTANTE', value_vars=['ANO-2014', 'ANO-2015'])
a2.value = a2["value"].astype(int)
a2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CLASE APORTANTE  56 non-null     object
#  1   variable         56 non-null     object
#  2   value            56 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.4+ KB

# %%
plt.figure(figsize=(12,4))
sns.histplot(y=df2["CLASE APORTANTE"],x=df2["value"].sum(), hue=df2["variable"])
# Out:
# <AxesSubplot:ylabel='CLASE APORTANTE'>

# %%
sns.histplot(x=df2.value)
# Out:
# <AxesSubplot:xlabel='value', ylabel='Count'>

# %%
sns.boxplot(x=a["value"], y=a["variable"])
# Out:
# <AxesSubplot:xlabel='value', ylabel='variable'>

# %%
#  Reconstruyendo dataframe en 3 filas

df2 = pd.melt(df1, id_vars='CLASE APORTANTE', value_vars=['ANO-2014', 'ANO-2015', 'ANO-2016',
                                                          'ANO-2017', 'ANO-2018', 'ANO-2019',
                                                          'ANO-2020', 'ANO-2021'])

# %%
df2.head()
# Out:
#                                      CLASE APORTANTE  variable          value
# 0                     Hoteles y Centros Vacacionales  ANO-2014    8258014655
# 1  Viviendas Turísticas u otro tipo de hospedaje ...  ANO-2014     253062203
# 2                                 Agencias de Viajes  ANO-2014    2370773024
# 3                Oficina de Representación Turística  ANO-2014     195130444
# 4                                  Deportes naúticos  ANO-2014       7606910

# %%
df2.value = df2["value"].astype(int)

# %%
plt.figure(figsize=(12,4))
plt.title("Contribución Parafiscal Turismo Colombia Periodo 2014 - 2022")
ax = sns.barplot(data = df2, x='variable', y='value')#,hue=df2["CLASE APORTANTE"]
ax.set_xlabel("Periodos")
ax.set_ylabel("Aportes Moneda Colombiana")
# Out:
# Text(0, 0.5, 'Aportes Moneda Colombiana')

# %%
a = df2.groupby("CLASE APORTANTE")["value"].sum().plot(kind="barh",legend="Reverse")
a
# Out:
# <AxesSubplot:ylabel='CLASE APORTANTE'>

# %%
a = df2.groupby("CLASE APORTANTE")["value"].mean().plot(kind="pie")
plt.axis("equal")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
g=sns.pairplot(df2, hue="variable", palette="Spectral")

# %%
plt.figure(figsize=(12,6))
plt.title("Contribución Parafiscal Turismo Colombia Por Tipo Aportante Periodo 2014 - 2022")
ax = sns.barplot(data = df2, x='variable', y='value',hue=df2["CLASE APORTANTE"])
ax.set_xlabel("Periodos")
ax.set_ylabel("Aportes Moneda Colombiana")
plt.legend(bbox_to_anchor=(1, 1), loc=2)

# %%
plt.figure(figsize=(12,6))
plt.title("Contribución Parafiscal Turismo Colombia Por Tipo Aportante Periodo 2014 - 2022")
ax = sns.barplot(data = df2, x='value', y=df2["CLASE APORTANTE"])
ax.set_xlabel("Periodos")
ax.set_ylabel("Aportes Moneda Colombiana")
plt.legend(bbox_to_anchor=(1, 1), loc=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df2.head()
# Out:
#                                      CLASE APORTANTE  variable       value
# 0                     Hoteles y Centros Vacacionales  ANO-2014  8258014655
# 1  Viviendas Turísticas u otro tipo de hospedaje ...  ANO-2014   253062203
# 2                                 Agencias de Viajes  ANO-2014  2370773024
# 3                Oficina de Representación Turística  ANO-2014   195130444
# 4                                  Deportes naúticos  ANO-2014     7606910

# %%
DATA.head()
# Out:
#                                      CLASE APORTANTE       ANO-2014  \
# 0                     Hoteles y Centros Vacacionales    8258014655
# 1  Viviendas Turísticas u otro tipo de hospedaje ...     253062203
# 2                                 Agencias de Viajes    2370773024
# 3                Oficina de Representación Turística     195130444
# 4                                  Deportes naúticos       7606910
#
#         ANO-2015        ANO-2016        ANO-2017        ANO-2018  \
# 0    9370587368     10865531432     11700296314     13717612224
# 1     306329082       368429386       426940968       662194250
# 2    2605481965      2976564291      3211374588      3881301106
# 3     199788688       196877323       181569000       208531000
# 4       8940064         7729342        12520000        19088000
#
#          ANO-2019       ANO-2020        ANO-2021
# 0    15053610576     8780051895     10179038000
# 1      796846000      559716000       864590000
# ...

# %%
frecuencia = pd.crosstab(DATA["CLASE APORTANTE"], DATA["ANO-2021"], normalize = True)
frecuencia
# Out:
# ANO-2021                                                -       10179038000   \
# CLASE APORTANTE
# Agencias de Viajes                                  0.000000        0.000000
# Arrendadores de Vehiculos                           0.000000        0.000000
# Bares y restaurantes turísticos                     0.000000        0.000000
# Centros de convenciones                             0.000000        0.000000
# Centros terapéuticos o balnearios                   0.000000        0.000000
# Comercializadora Proyecto Tiempo Compartido y M...  0.000000        0.000000
# Concesionarios de Aeropuertos y Carreteras          0.000000        0.000000
# Concesionarios parques                              0.000000        0.000000
# Deportes naúticos                                   0.000000        0.000000
# Empresas de seguros de viaje y de asistencia mé...  0.000000        0.000000
# Empresas de transporte de pasajeros aéreos          0.000000        0.000000
# ...

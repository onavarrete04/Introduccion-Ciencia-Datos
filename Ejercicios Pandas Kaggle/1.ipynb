# %%
# importando pandas
import pandas as pd

# %%
# creando dos objetos en pandas
# un data frame es una tabla, contiene un array individual y entradas, cada cual tiene cierto valur
# cada entrada corresponde a un registo o fila y a una columna

pd.DataFrame({"Yes":[50,21],"No":[131,2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({"Bob":["Me gusta esto", "Es bonito"], "Sue":["Muy lindo","Bland"]})
# Out:
#              Bob        Sue
# 0  Me gusta esto  Muy lindo
# 1      Es bonito      Bland

# %%
# podemos asignar un indice que nos guste
# un dataframe esta representado por un conjunto

pd.DataFrame({"Bob":["Mayonesa","Salame"],
             "Sue":["Platanos", "Huevos"]},
            index = ["Tienda A", "Tienda B"])
# Out:
#                Bob       Sue
# Tienda A  Mayonesa  Platanos
# Tienda B    Salame    Huevos

# %%
#Series
# una serie es una consecución de datos que puede ser entendida como una lista

pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30,35,40], index=["2015 ventas", "2016 Ventas","2017 ventas"], name="Producto A")
# Out:
# 2015 ventas    30
# 2016 Ventas    35
# 2017 ventas    40
# Name: Producto A, dtype: int64

# %%
# importando datso

import pandas as pd

datos = pd.read_csv("../base.csv")
datos.head()
# Out:
#    CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 0         11     0    23      8            12    800  1.603808
# 1         11     1    23      2            12   1150  1.739790
# 2         11     1    35      8            15    880  1.760444
# 3         11     0    46      2             6   3500  1.783158
# 4         11     1    47      8             9    150  1.690631

# %%
datos.Sexo
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 76835    1
# 76836    0
# 76837    0
# 76838    0
# 76839    0
# Name: Sexo, Length: 76840, dtype: int64

# %%
datos.Sexo[1]
# Out:
# 1

# %%
datos.Sexo[0:5]
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: Sexo, dtype: int64

# %% [markdown]
# # ILOC

# %%
# Indexación basada en operadores con iloc

datos.iloc[0]
# Out:
# CodPostal        11.000000
# Sexo              0.000000
# Edad             23.000000
# Color             8.000000
# Años_Estudio     12.000000
# Renta           800.000000
# Altura            1.603808
# Name: 0, dtype: float64

# %%
# primero van filas y luego van columnas, por lo cual es más
# sencillo recuperar filas que columnas

# %%
# recuperando una columna

print(datos.iloc[:,0])
print("---"*8)
print(datos.iloc[0:5,0])
# esto es lo mismo que hacer

datos.CodPostal
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 76835    53
# 76836    53
# 76837    53
# 76838    53
# 76839    53
# Name: CodPostal, Length: 76840, dtype: int64
# ------------------------
# 0    11
# 1    11
# 2    11
# 3    11
# 4    11
# Name: CodPostal, dtype: int64
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 76835    53
# 76836    53
# 76837    53
# 76838    53
# 76839    53
# Name: CodPostal, Length: 76840, dtype: int64

# %%
# en python el selector : significa todo y muestra todo, pero
# también puede usarse el selector con otras especificaciones

datos.iloc[:3, 1]

# estamos viendo a sexo, las primeras 3 columnas, primero asignamos las filas y luego las columnas
# Out:
# 0    0
# 1    1
# 2    1
# Name: Sexo, dtype: int64

# %%
datos.iloc[3:, 1]
# Out:
# 3        0
# 4        1
# 5        1
# 6        0
# 7        1
#         ..
# 76835    1
# 76836    0
# 76837    0
# 76838    0
# 76839    0
# Name: Sexo, Length: 76837, dtype: int64

# %%
datos.iloc[1:3, 1]

# seleccionamos las primeras dos filas
# Out:
# 1    1
# 2    1
# Name: Sexo, dtype: int64

# %%
# también es posible pasar una lista

datos.iloc[[0,1,2,3],1]

# esta lista indica que estamos biendo los registros con posición, 1,2,3 teniendo en cuenta que el 1 en python es 0
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# Name: Sexo, dtype: int64

# %%
# también trabaja con datos negativos, por ejemplo si ponemos -2 comienza desde el 0 y cuenta los últimos datos
datos.iloc[-5:, 1]
# Out:
# 76835    1
# 76836    0
# 76837    0
# 76838    0
# 76839    0
# Name: Sexo, dtype: int64

# %%
# para verlo como una lista sería

datos.iloc[[0,-1,-2,-3,-4,-5], 1]
# el 0 es para verificar el primer dato y como comienza hacia atras
# Out:
# 0        0
# 76839    0
# 76838    0
# 76837    0
# 76836    0
# 76835    1
# Name: Sexo, dtype: int64

# %% [markdown]
# # LOC

# %%
# En loc primeo va la fila y luego la columna

datos.loc[1:2, "Renta"]

# muestra que dato esta en la posición o registro 2 en la columna renta
# Out:
# 1    1150
# 2     880
# Name: Renta, dtype: int64

# %%
datos.loc[1:3, "Renta"]
# Out:
# 1    1150
# 2     880
# 3    3500
# Name: Renta, dtype: int64

# %%
# iloc funciona como matrices, es decir, listas anidadas omitiendo los indices

# loc no lo hace, este si tieen en cuenta las listas

datos.loc[:,["Sexo","Renta","Altura"]]

# en este caso estamos manejando los datos de 3 columnas junto a todas sus filas
# Out:
#        Sexo  Renta    Altura
# 0         0    800  1.603808
# 1         1   1150  1.739790
# 2         1    880  1.760444
# 3         0   3500  1.783158
# 4         1    150  1.690631
# ...     ...    ...       ...
# 76835     1    812  1.687030
# 76836     0   1500  1.792934
# 76837     0   1300  1.830587
# 76838     0   1500  1.726344
# 76839     0    900  1.658305
#
# [76840 rows x 3 columns]

# %% [markdown]
# iloc usa el esquema de indexación stdlib de Python, donde se incluye el primer elemento del rango y se excluye el último. Entonces 0:10 seleccionará las entradas 0,...,9. loc, por su parte, indexa inclusive. Entonces 0:10 seleccionará las entradas 0,...,10.

# %%
datos.set_index("Altura") 

# set_index() utiliza una columna de index, en este caso ahora la altura es el index
# Out:
#           CodPostal  Sexo  Edad  Color  Años_Estudio  Renta
# Altura
# 1.603808         11     0    23      8            12    800
# 1.739790         11     1    23      2            12   1150
# 1.760444         11     1    35      8            15    880
# 1.783158         11     0    46      2             6   3500
# 1.690631         11     1    47      8             9    150
# ...             ...   ...   ...    ...           ...    ...
# 1.687030         53     1    46      2            11    812
# 1.792934         53     0    30      4             7   1500
# 1.830587         53     0    32      8            12   1300
# 1.726344         53     0    57      8             4   1500
# 1.658305         53     0    38      8             4    900
#
# [76840 rows x 6 columns]

# %%
# condicionales, podemos hacer preguntas

datos.Sexo == 1
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 76835     True
# 76836    False
# 76837    False
# 76838    False
# 76839    False
# Name: Sexo, Length: 76840, dtype: bool

# %%
# entonces podemos usar solo este tipo de género en el data frame

color = datos.loc[datos.Color == 4]
color
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 8             11     1    50      4            14   1800  1.780329
# 39            11     0    47      4             9   1500  1.672258
# 64            11     1    36      4            12   1000  1.704955
# 66            11     0    49      4            10   1000  1.810540
# 67            11     1    44      4            10    800  1.741427
# ...          ...   ...   ...    ...           ...    ...       ...
# 76812         53     1    32      4            12    788  1.681405
# 76813         53     0    35      4             9   2100  1.671112
# 76833         53     0    30      4             6   1900  1.662560
# 76834         53     1    35      4             1   1100  1.741089
# 76836         53     0    30      4             7   1500  1.792934
#
# [8391 rows x 7 columns]

# %%
datos.loc[(datos.Color == 2) & (datos.Altura >= 1.96)]
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 9112          15     0    23      2            13   1800  1.962313
# 10739         17     0    38      2            12   2500  1.977517
# 18398         24     1    52      2            13   1000  1.994329
# 22819         26     0    46      2            16   9000  1.977538
# 23417         26     1    64      2             1   4000  1.965178
# 34066         31     0    54      2             6    750  1.992238
# 35854         31     1    51      2            16   1540  1.986338
# 37656         31     1    75      2             1    100  1.984029
# 41815         33     0    42      2            14   2364  1.962974
# 46871         35     0    58      2             4   1000  1.968221
# 47636         35     0    63      2            12   5000  1.974575
# 49540         35     0    32      2            12   1600  2.000559
# 52632         35     1    50      2            16   2200  1.980167
# ...

# %%
datos.loc[(datos.Color == 2) | (datos.Altura >= 1.96)]
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 1             11     1    23      2            12   1150  1.739790
# 3             11     0    46      2             6   3500  1.783158
# 12            11     1    52      2             6   1200  1.736442
# 14            11     0    45      2            12   2000  1.780450
# 15            11     0    34      2            16   6000  1.711825
# ...          ...   ...   ...    ...           ...    ...       ...
# 76828         53     0    62      2            16  10000  1.817097
# 76830         53     0    62      2            16   3500  1.725379
# 76831         53     1    44      2            16  30000  1.783962
# 76832         53     1    49      2            12   5000  1.757146
# 76835         53     1    46      2            11    812  1.687030
#
# [31835 rows x 7 columns]

# %%
# selector isin es un selector prediseñado que debe enviarse en formato de lista


datos.loc[datos.Color.isin([2,4])]
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 1             11     1    23      2            12   1150  1.739790
# 3             11     0    46      2             6   3500  1.783158
# 8             11     1    50      4            14   1800  1.780329
# 12            11     1    52      2             6   1200  1.736442
# 14            11     0    45      2            12   2000  1.780450
# ...          ...   ...   ...    ...           ...    ...       ...
# 76832         53     1    49      2            12   5000  1.757146
# 76833         53     0    30      4             6   1900  1.662560
# 76834         53     1    35      4             1   1100  1.741089
# 76835         53     1    46      2            11    812  1.687030
# 76836         53     0    30      4             7   1500  1.792934
#
# [40206 rows x 7 columns]

# %% [markdown]
# El segundo es isnull (y su compañero notnull). Estos métodos le permiten resaltar valores que están (o no están) vacíos (NaN).

# %%
# selector isnull

datos.loc[datos.Altura.notnull()]
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 0             11     0    23      8            12    800  1.603808
# 1             11     1    23      2            12   1150  1.739790
# 2             11     1    35      8            15    880  1.760444
# 3             11     0    46      2             6   3500  1.783158
# 4             11     1    47      8             9    150  1.690631
# ...          ...   ...   ...    ...           ...    ...       ...
# 76835         53     1    46      2            11    812  1.687030
# 76836         53     0    30      4             7   1500  1.792934
# 76837         53     0    32      8            12   1300  1.830587
# 76838         53     0    57      8             4   1500  1.726344
# 76839         53     0    38      8             4    900  1.658305
#
# [76840 rows x 7 columns]

# %%
a = datos

# %%
a["Altura"] = "Estatura"

# %%
a
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 0             11     0    23      8            12    800  Estatura
# 1             11     1    23      2            12   1150  Estatura
# 2             11     1    35      8            15    880  Estatura
# 3             11     0    46      2             6   3500  Estatura
# 4             11     1    47      8             9    150  Estatura
# ...          ...   ...   ...    ...           ...    ...       ...
# 76835         53     1    46      2            11    812  Estatura
# 76836         53     0    30      4             7   1500  Estatura
# 76837         53     0    32      8            12   1300  Estatura
# 76838         53     0    57      8             4   1500  Estatura
# 76839         53     0    38      8             4    900  Estatura
#
# [76840 rows x 7 columns]

# %%
a["Altura"] = range(len(a), 0, -1)
a

# aqui lo que hizo es que hizo un rango y fue enumerando uno por uno desde el descendentemente
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta  Altura
# 0             11     0    23      8            12    800   76840
# 1             11     1    23      2            12   1150   76839
# 2             11     1    35      8            15    880   76838
# 3             11     0    46      2             6   3500   76837
# 4             11     1    47      8             9    150   76836
# ...          ...   ...   ...    ...           ...    ...     ...
# 76835         53     1    46      2            11    812       5
# 76836         53     0    30      4             7   1500       4
# 76837         53     0    32      8            12   1300       3
# 76838         53     0    57      8             4   1500       2
# 76839         53     0    38      8             4    900       1
#
# [76840 rows x 7 columns]

# %%
datos.Renta.unique()
# Out:
# array([  800,  1150,   880, ..., 36000,  1329,  5260])

# %%
media_renta = datos.Renta.mean()
datos.Renta.map(lambda i: i - media_renta)
# Out:
# 0       -1200.383199
# 1        -850.383199
# 2       -1120.383199
# 3        1499.616801
# 4       -1850.383199
#             ...
# 76835   -1188.383199
# 76836    -500.383199
# 76837    -700.383199
# 76838    -500.383199
# 76839   -1100.383199
# Name: Renta, Length: 76840, dtype: float64

# %%
# función map 

lista = [2,3,4,5,6]

dobles = list(map(lambda x: x*2, lista))
dobles
# Out:
# [4, 6, 8, 10, 12]

# %%
# Ejemplo, de suma de dos valores que dan true a partir de la suma de booleanos

'''
tropical = reviews.description.map(lambda i: "tropical" in i).sum()
fruity = reviews.description.map(lambda i: "fruity" in i).sum()
descriptor_counts = pd.Series([tropical, fruity],index = ["tropical","fruity"])
print(descriptor_counts)

# Check your answer
q6.check()
'''
# Out:
# '\ntropical = reviews.description.map(lambda i: "tropical" in i).sum()\nfruity = reviews.description.map(lambda i: "fruity" in i).sum()\ndescriptor_counts = pd.Series([tropical, fruity],index = ["tropical","fruity"])\nprint(descriptor_counts)\n\n# Check your answer\nq6.check()\n'

# %%
"""
Ejercicio en donde se cambia las calificaciones por fila


def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = reviews.apply(stars, axis='columns')
"""
# Out:
# "\nEjercicio en donde se cambia las calificaciones por fila\n\n\ndef stars(row):\n    if row.country == 'Canada':\n        return 3\n    elif row.points >= 95:\n        return 3\n    elif row.points >= 85:\n        return 2\n    else:\n        return 1\n\nstar_ratings = reviews.apply(stars, axis='columns')\n"

# %% [markdown]
# Análisis por grupos
# Una función que hemos estado usando mucho hasta ahora es la función value_counts(). Podemos replicar lo que hace value_counts() haciendo lo siguiente:

# %%
datos.groupby("Renta").Renta.count()
# Out:
# Renta
# 0         2867
# 5            1
# 6            1
# 8            2
# 10           9
#           ...
# 80000        4
# 90000        1
# 100000       6
# 120000       1
# 200000       3
# Name: Renta, Length: 1606, dtype: int64

# %%
datos.Renta.mode()
# Out:
# 0    788
# Name: Renta, dtype: int64

# %%
datos.groupby("Renta").value_counts()
# Out:
# Renta   CodPostal  Sexo  Edad  Color  Años_Estudio  Altura
# 0       11         0     39    8      10            1.883402    1
#                          49    8      2             1.798254    1
#         43         0     73    2      9             1.532363    1
#                                       4             1.775243    1
#                          72    8      4             1.687820    1
#                                                                ..
# 100000  31         0     46    8      16            1.724601    1
# 120000  33         1     53    0      13            1.661979    1
# 200000  33         0     79    2      16            1.681105    1
#         29         0     51    2      12            1.587794    1
#         41         0     42    2      16            1.580848    1
# Length: 76840, dtype: int64

# %%
datos.groupby("Altura").Renta.min()
# Se supone que esta mostrando las alturas según 
# el sueldo más bajito por cada una de las alturas.
# Out:
# Altura
# 1.339245    3900
# 1.369494     600
# 1.382390    1500
# 1.393778     200
# 1.398523    2100
#             ...
# 2.000559    1600
# 2.001359     480
# 2.004185    1400
# 2.015830     788
# 2.028497    1200
# Name: Renta, Length: 76831, dtype: int64

# %%
datos.groupby("Color").Renta.max()
# esta asignando los colores por la renta más alta
# Out:
# Color
# 0    120000
# 2    200000
# 4     50000
# 6     50000
# 8    100000
# Name: Renta, dtype: int64

# %%
datos.groupby("Color").Renta.min()

# vemos que hay rentas minimas también
# Out:
# Color
# 0    0
# 2    0
# 4    0
# 6    0
# 8    0
# Name: Renta, dtype: int64

# %%
datos.groupby("Color").apply(lambda i: i.Sexo.iloc[0])
# Out:
# Color
# 0    0
# 2    1
# 4    1
# 6    0
# 8    0
# dtype: int64

# %%
datos.Sexo.iloc[0]
# Out:
# 0

# %%
"""
selecciona el mejor pais y provincia por el mejor vino

reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])


"""
# Out:
# "\nselecciona el mejor pais y provincia por el mejor vino\n\nreviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])\n\n\n"

# %%
"""
Puede pensar en cada grupo que generamos como una porción de nuestro DataFrame que contiene solo datos 
con valores que coinciden. Este DataFrame es accesible para nosotros directamente usando el método apply(),
y luego podemos manipular los datos de la forma que mejor nos parezca. Por ejemplo, aquí hay una forma de 
seleccionar el nombre del primer vino revisado de cada bodega en el conjunto de datos:

reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
"""
# Out:
# "\nPuede pensar en cada grupo que generamos como una porción de nuestro DataFrame que contiene solo datos \ncon valores que coinciden. Este DataFrame es accesible para nosotros directamente usando el método apply(),\ny luego podemos manipular los datos de la forma que mejor nos parezca. Por ejemplo, aquí hay una forma de \nseleccionar el nombre del primer vino revisado de cada bodega en el conjunto de datos:\n\nreviews.groupby('winery').apply(lambda df: df.title.iloc[0])\n"

# %%
datos.groupby(["Sexo", "Color"]).apply(lambda i: i.loc[i.Renta.idxmax()])

#coloca los sexos y el color de las mayores rentas.
# Out:
#             CodPostal  Sexo  Edad  Color  Años_Estudio     Renta    Altura
# Sexo Color
# 0    0           31.0   0.0  58.0    0.0          12.0   10000.0  1.587622
#      2           29.0   0.0  51.0    2.0          12.0  200000.0  1.587794
#      4           26.0   0.0  39.0    4.0          12.0   50000.0  1.613302
#      6           15.0   0.0  59.0    6.0          12.0   50000.0  1.718788
#      8           31.0   0.0  46.0    8.0          16.0  100000.0  1.724601
# 1    0           33.0   1.0  53.0    0.0          13.0  120000.0  1.661979
#      2           32.0   1.0  71.0    2.0          16.0  100000.0  1.793337
#      4           53.0   1.0  50.0    4.0          16.0   23000.0  1.701536
#      6           50.0   1.0  37.0    6.0          16.0   20000.0  1.709478
#      8           22.0   1.0  58.0    8.0          16.0   30000.0  1.674623

# %% [markdown]
# Otro método groupby() que vale la pena mencionar es agg(), que le permite ejecutar varias funciones diferentes en su DataFrame simultáneamente. Por ejemplo, podemos generar un resumen estadístico simple del conjunto de datos de la siguiente manera:

# %%
"""reviews.groupby(['country']).price.agg([len, min, max])"""

datos.groupby(["Color"]).Renta.agg([len,min,max])
# Out:
#          len  min     max
# Color
# 0        357    0  120000
# 2      31815    0  200000
# 4       8391    0   50000
# 6        352    0   50000
# 8      35925    0  100000

# %% [markdown]
# Multi-índices
# En todos los ejemplos que hemos visto hasta ahora, hemos estado trabajando con objetos DataFrame o Series con un índice de etiqueta única. groupby() es ligeramente diferente en el hecho de que, dependiendo de la operación que ejecutemos, a veces resultará en lo que se llama un índice múltiple.
#
# Un índice múltiple difiere de un índice regular en que tiene múltiples niveles. Por ejemplo:

# %%
"""
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed

"""

Color_Datos = datos.groupby(["Color","Años_Estudio"]).Renta.agg([len])
Color_Datos.head(40)
# Out:
#                      len
# Color Años_Estudio
# 0     1               49
#       2               10
#       3               12
#       4               17
#       5               22
#       6               23
#       7               12
#       8               16
#       9               45
#       10              16
#       11              12
#       12              82
#       13               7
#       14               5
#       15               6
#       16              20
#       17               3
# 2     1             1420
#       2              364
#       3              617
#       4              929
#       5             2683
#       6             1600
#       7              860
#       8              940
#       9             3102
#       10             558
#       11             779
#       12            8838
#       13             869
#       14             663
#       15             773
#       16            6758
#       17              62
# 4     1              801
# ...

# %%
a = Color_Datos.index

type(a)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# Los índices múltiples tienen varios métodos para manejar su estructura escalonada que están ausentes en los índices de un solo nivel. También requieren dos niveles de etiquetas para recuperar un valor. Tratar con la salida de múltiples índices es un problema común para los usuarios nuevos en pandas.
#
# Los casos de uso para un índice múltiple se detallan junto con las instrucciones sobre cómo usarlos en la sección MultiÍndice/Selección avanzada de la documentación de pandas.
#
# Sin embargo, en general, el método de múltiples índices que usará con más frecuencia es el que se utiliza para volver a convertir a un índice normal, el método reset_index().

# %%
"""countries_reviewed.reset_index()"""

Color_Datos.reset_index()
# Out:
#     Color  Años_Estudio   len
# 0       0             1    49
# 1       0             2    10
# 2       0             3    12
# 3       0             4    17
# 4       0             5    22
# ..    ...           ...   ...
# 79      8            13   762
# 80      8            14   464
# 81      8            15   483
# 82      8            16  3174
# 83      8            17   105
#
# [84 rows x 3 columns]

# %% [markdown]
# Clasificación
# Mirando nuevamente a los países_revisados, podemos ver que la agrupación devuelve los datos en orden de índice, no en orden de valor. Es decir, al generar el resultado de un groupby, el orden de las filas depende de los valores en el índice, no en los datos.
#
# Para obtener los datos en el orden en que los queremos, podemos ordenarlos nosotros mismos. El método sort_values() es útil para esto.

# %%
"""countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')"""

Color_Datos = Color_Datos.reset_index()
Color_Datos.sort_values(by="len")

# organiza los datos respecto a la cantidad de valores por el metodo len
# Out:
#     Color  Años_Estudio   len
# 53      6             3     1
# 58      6             8     1
# 60      6            10     2
# 52      6             2     2
# 54      6             4     3
# ..    ...           ...   ...
# 67      8             1  3570
# 75      8             9  3907
# 32      2            16  6758
# 28      2            12  8838
# 78      8            12  9417
#
# [84 rows x 3 columns]

# %% [markdown]
# sort_values() por defecto es una ordenación ascendente, donde los valores más bajos van primero. Sin embargo, la mayoría de las veces queremos un orden descendente, donde los números más altos van primero. Eso va así:

# %%
"""countries_reviewed.sort_values(by='len', ascending=False)"""
Color_Datos.sort_values(by="len", ascending = False)
# Out:
#     Color  Años_Estudio   len
# 78      8            12  9417
# 28      2            12  8838
# 32      2            16  6758
# 75      8             9  3907
# 67      8             1  3570
# ..    ...           ...   ...
# 54      6             4     3
# 52      6             2     2
# 60      6            10     2
# 53      6             3     1
# 58      6             8     1
#
# [84 rows x 3 columns]

# %% [markdown]
# Para ordenar por valores de índice, utilice el método complementario sort_index(). Este método tiene los mismos argumentos y orden predeterminado:

# %%
"""countries_reviewed.sort_index()"""

Color_Datos.sort_index()
# Out:
#     Color  Años_Estudio   len
# 0       0             1    49
# 1       0             2    10
# 2       0             3    12
# 3       0             4    17
# 4       0             5    22
# ..    ...           ...   ...
# 79      8            13   762
# 80      8            14   464
# 81      8            15   483
# 82      8            16  3174
# 83      8            17   105
#
# [84 rows x 3 columns]

# %% [markdown]
# Finalmente, sepa que puede ordenar por más de una columna a la vez:

# %%
"""countries_reviewed.sort_values(by=['country', 'len'])"""

Color_Datos.sort_values(by=["Años_Estudio","len"])
# Out:
#     Color  Años_Estudio   len
# 51      6             1     9
# 0       0             1    49
# 34      4             1   801
# 17      2             1  1420
# 67      8             1  3570
# ..    ...           ...   ...
# 32      2            16  6758
# 16      0            17     3
# 50      4            17    21
# 33      2            17    62
# 83      8            17   105
#
# [84 rows x 3 columns]

# %%
"""
¿Quiénes son los revisores de vinos más comunes en el conjunto de datos? Cree una serie cuyo índice sea 
la categoría catador_twitter_handle del conjunto de datos y cuyos valores cuenten cuántas reseñas escribió 
cada persona.


soluciones

# Your code here
reviews_written = reviews.groupby(["taster_twitter_handle"]).size()

reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()

"""
# Out:
# '\n¿Quiénes son los revisores de vinos más comunes en el conjunto de datos? Cree una serie cuyo índice sea \nla categoría catador_twitter_handle del conjunto de datos y cuyos valores cuenten cuántas reseñas escribió \ncada persona.\n\n\nsoluciones\n\n# Your code here\nreviews_written = reviews.groupby(["taster_twitter_handle"]).size()\n\nreviews_written = reviews.groupby(\'taster_twitter_handle\').taster_twitter_handle.count()\n\n'

# %%
"""
¿Cuál es el mejor vino que puedo comprar por una determinada cantidad de dinero? 
Cree una serie cuyo índice sean los precios de los vinos y cuyo valor sea el número máximo de 
puntos que se le dio a un vino que cuesta tanto en una reseña. Ordene los valores por precio, de 
forma ascendente (de modo que 4,0 dólares esté en la parte superior
y 3300,0 dólares en la parte inferior).

best_rating_per_price = reviews.groupby(["price"]).points.max()

"""
# Out:
# '\n¿Cuál es el mejor vino que puedo comprar por una determinada cantidad de dinero? \nCree una serie cuyo índice sean los precios de los vinos y cuyo valor sea el número máximo de \npuntos que se le dio a un vino que cuesta tanto en una reseña. Ordene los valores por precio, de \nforma ascendente (de modo que 4,0 dólares esté en la parte superior\ny 3300,0 dólares en la parte inferior).\n\nbest_rating_per_price = reviews.groupby(["price"]).points.max()\n\n'

# %%
"""
¿Cuáles son los precios mínimos y máximos para cada variedad de vino? Cree un DataFrame cuyo índice
sea la categoría de variedad del conjunto de datos y cuyos valores sean los valores mínimo
y máximo del mismo.

price_extremes = reviews.groupby(["variety"]).price.agg([min,max])
"""
# Out:
# '\n¿Cuáles son los precios mínimos y máximos para cada variedad de vino? Cree un DataFrame cuyo índice\nsea la categoría de variedad del conjunto de datos y cuyos valores sean los valores mínimo\ny máximo del mismo.\n\nprice_extremes = reviews.groupby(["variety"]).price.agg([min,max])\n'

# %%
"""
¿Cuáles son las variedades de vino más caras? Cree una variable sorted_variedades que contenga 
una copia del marco de datos de la pregunta anterior donde las variedades se clasifican en orden
descendente según el precio mínimo y luego el precio máximo (para desempatar).


sorted_varieties = price_extremes.sort_values(by=["min","max"], ascending=False)
"""
# Out:
# '\n¿Cuáles son las variedades de vino más caras? Cree una variable sorted_variedades que contenga \nuna copia del marco de datos de la pregunta anterior donde las variedades se clasifican en orden\ndescendente según el precio mínimo y luego el precio máximo (para desempatar).\n\n\nsorted_varieties = price_extremes.sort_values(by=["min","max"], ascending=False)\n'

# %%
"""
Cree una serie cuyo índice sean los revisores y cuyos valores 
sean la puntuación de revisión promedio otorgada por ese revisor. Sugerencia: necesitará las columnas 
nombre_degustador y puntos.


reviewer_mean_ratings = reviews.groupby(["taster_name"]).points.mean()
"""
# Out:
# '\nCree una serie cuyo índice sean los revisores y cuyos valores \nsean la puntuación de revisión promedio otorgada por ese revisor. Sugerencia: necesitará las columnas \nnombre_degustador y puntos.\n\n\nreviewer_mean_ratings = reviews.groupby(["taster_name"]).points.mean()\n'

# %%
datos.head()
# Out:
#    CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura
# 0         11     0    23      8            12    800  1.603808
# 1         11     1    23      2            12   1150  1.739790
# 2         11     1    35      8            15    880  1.760444
# 3         11     0    46      2             6   3500  1.783158
# 4         11     1    47      8             9    150  1.690631

# %%
datos.Sexo.dtype
# Out:
# dtype('int64')

# %%
datos.dtypes
# Out:
# CodPostal         int64
# Sexo              int64
# Edad              int64
# Color             int64
# Años_Estudio      int64
# Renta             int64
# Altura          float64
# dtype: object

# %% [markdown]
# dtype o dtypes es para conocer el tipo de dato de una columna

# %%
# cambiar el tipo de dato es astype


a = datos
a["Edad_Repetido"] = a["Edad"].replace()

a.Edad_Repetido.astype(float)

a.dtypes
# Out:
# CodPostal          int64
# Sexo               int64
# Edad               int64
# Color              int64
# Años_Estudio       int64
# Renta              int64
# Altura           float64
# Edad_Repetido      int64
# dtype: object

# %%
datos.index.dtype

# el index de nuestros dataframe también tienen
# dtype
# Out:
# dtype('int64')

# %% [markdown]
# Datos perdidos
# A las entradas que faltan valores se les asigna el valor NaN, abreviatura de "No es un número". Por razones técnicas, estos valores de NaN son siempre del tipo float64 d.
#
# Pandas proporciona algunos métodos específicos para los datos que faltan. Para seleccionar entradas de NaN, puede usar pd.isnull() (o su compañero pd.notnull()). Esto está destinado a ser utilizado así:

# %%
datos[pd.isnull(datos.Edad)]
# Out:
# Empty DataFrame
# Columns: [CodPostal, Sexo, Edad, Color, Años_Estudio, Renta, Altura, Edad_Repetido]
# Index: []

# %%
# fillna()  # para remplazar datos NaN

# NaN Significa Not  A Number y es un estandar

#  reviews.region_2.fillna("Unknown")

datos.Edad.fillna("Desconocidos")

# como todos los datos estan llenos no hay desconocidos
# Out:
# 0        23
# 1        23
# 2        35
# 3        46
# 4        47
#          ..
# 76835    46
# 76836    30
# 76837    32
# 76838    57
# 76839    38
# Name: Edad, Length: 76840, dtype: int64

# %%
# replace para remplazar datos, para ello normalmente yo he creado una nueva columna de datos

"""reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")"""

a.Edad_Repetido.replace(23, 233) # cambie los datos que aparecian en 23 por años 233
# Out:
# 0        233
# 1        233
# 2         35
# 3         46
# 4         47
#         ...
# 76835     46
# 76836     30
# 76837     32
# 76838     57
# 76839     38
# Name: Edad_Repetido, Length: 76840, dtype: int64

# %%
# contar columnas con datos nulos

# n_missing_prices = pd.isnull(reviews.price).sum()

# %% [markdown]
# ¿Cuáles son las regiones productoras de vino más comunes? Cree una serie que cuente la cantidad de veces que aparece cada valor en el campo region_1. A este campo a menudo le faltan datos, así que reemplace los valores faltantes con Desconocido. Ordenar en orden descendente. Su salida debería ser algo como esto:
#
#
# Cantidad de veces cada valor es value_counts()
#
# fillna() eliminar Nan por otro dato
#
# sort_values() ordenar los valores

# %%
# rename()   cambia nombre de index o de columna

a.rename(columns={"Edad_Repetido":"Columna_Edad_Repetida"})
# Out:
#        CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura  \
# 0             11     0    23      8            12    800  1.603808
# 1             11     1    23      2            12   1150  1.739790
# 2             11     1    35      8            15    880  1.760444
# 3             11     0    46      2             6   3500  1.783158
# 4             11     1    47      8             9    150  1.690631
# ...          ...   ...   ...    ...           ...    ...       ...
# 76835         53     1    46      2            11    812  1.687030
# 76836         53     0    30      4             7   1500  1.792934
# 76837         53     0    32      8            12   1300  1.830587
# 76838         53     0    57      8             4   1500  1.726344
# 76839         53     0    38      8             4    900  1.658305
#
#        Columna_Edad_Repetida
# 0                         23
# 1                         23
# 2                         35
# 3                         46
# ...

# %%
# cambiando unos elementos del index 

a.rename(index={0:"Primera_Entrada",1:"Segunda_Entrada"})
# Out:
#                  CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura  \
# Primera_Entrada         11     0    23      8            12    800  1.603808
# Segunda_Entrada         11     1    23      2            12   1150  1.739790
# 2                       11     1    35      8            15    880  1.760444
# 3                       11     0    46      2             6   3500  1.783158
# 4                       11     1    47      8             9    150  1.690631
# ...                    ...   ...   ...    ...           ...    ...       ...
# 76835                   53     1    46      2            11    812  1.687030
# 76836                   53     0    30      4             7   1500  1.792934
# 76837                   53     0    32      8            12   1300  1.830587
# 76838                   53     0    57      8             4   1500  1.726344
# 76839                   53     0    38      8             4    900  1.658305
#
#                  Edad_Repetido
# ...

# %% [markdown]
# Tanto el índice de fila como el índice de columna pueden tener su propio atributo de nombre. El método complementario rename_axis() se puede utilizar para cambiar estos nombres. Por ejemplo:

# %%
a.rename_axis("Filas",axis="rows").rename_axis("columnas",axis="columns")
# Out:
# columnas  CodPostal  Sexo  Edad  Color  Años_Estudio  Renta    Altura  \
# Filas
# 0                11     0    23      8            12    800  1.603808
# 1                11     1    23      2            12   1150  1.739790
# 2                11     1    35      8            15    880  1.760444
# 3                11     0    46      2             6   3500  1.783158
# 4                11     1    47      8             9    150  1.690631
# ...             ...   ...   ...    ...           ...    ...       ...
# 76835            53     1    46      2            11    812  1.687030
# 76836            53     0    30      4             7   1500  1.792934
# 76837            53     0    32      8            12   1300  1.830587
# 76838            53     0    57      8             4   1500  1.726344
# 76839            53     0    38      8             4    900  1.658305
#
# columnas  Edad_Repetido
# Filas
# 0                    23
# 1                    23
# 2                    35
# ...

# %% [markdown]
# ombinatorio
# Al realizar operaciones en un conjunto de datos, a veces necesitaremos combinar diferentes DataFrames y/o Series de formas no triviales. Pandas tiene tres métodos básicos para hacer esto. En orden de complejidad creciente, estos son concat(), join() y merge(). La mayor parte de lo que puede hacer merge() también se puede hacer de forma más sencilla con join(), por lo que lo omitiremos y nos centraremos en las dos primeras funciones aquí.
#
# El método de combinación más simple es concat(). Dada una lista de elementos, esta función juntará esos elementos a lo largo de un eje.
#
# Esto es útil cuando tenemos datos en diferentes objetos DataFrame o Series pero que tienen los mismos campos (columnas). Un ejemplo: el conjunto de datos de videos de YouTube, que divide los datos según el país de origen (por ejemplo, Canadá y el Reino Unido, en este ejemplo). Si queremos estudiar varios países simultáneamente, podemos usar concat() para fusionarlos:

# %%
"""

canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])


"""
# Out:
# '\n\ncanadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")\nbritish_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")\n\npd.concat([canadian_youtube, british_youtube])\n\n\n'

# %% [markdown]
# El combinador más intermedio en términos de complejidad es join(). join() le permite combinar diferentes objetos DataFrame que tienen un índice en común. Por ejemplo, para ver videos que fueron tendencia el mismo día tanto en Canadá como en el Reino Unido, podríamos hacer lo siguiente:
#
#
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])
#
# left.join(right, lsuffix='_CAN', rsuffix='_UK')
#
#
# Los parámetros lsuffix y rsuffix son necesarios aquí porque los datos tienen los mismos nombres de columna en los conjuntos de datos británicos y canadienses. Si esto no fuera cierto (porque, digamos, les habíamos cambiado el nombre de antemano) no lo necesitaríamos

# %% [markdown]
# region_1 y region_2 son nombres bastante poco informativos para las columnas de configuración regional en el conjunto de datos. Cree una copia de las reseñas con estas columnas renombradas como región y localidad, respectivamente.
#
#
#         renamed = reviews.rename(columns={"region_1":"region","region_2":"locale"})
#
#
# 2.
# Establezca el nombre del índice en el conjunto de datos en vinos.
#
#
#         reindexed = reviews.rename_axis("wines",axis="rows")

# %% [markdown]
# # ¡Bienvenido al curso de limpieza de datos en Kaggle Learn!
#
# La limpieza de datos es una parte clave de la ciencia de datos, pero puede ser muy frustrante. ¿Por qué algunos de sus campos de texto están ilegibles? ¿Qué debe hacer con esos valores faltantes? ¿Por qué sus fechas no tienen el formato correcto? ¿Cómo puede limpiar rápidamente la entrada de datos inconsistentes? En este curso, aprenderá por qué se ha encontrado con estos problemas y, lo que es más importante, cómo solucionarlos.
#
# En este curso, aprenderá cómo abordar algunos de los problemas de limpieza de datos más comunes para poder analizar sus datos más rápido. Trabajará en cinco ejercicios prácticos con datos reales desordenados y responderá algunas de las preguntas más frecuentes sobre la limpieza de datos.
#
# En este cuaderno, veremos cómo lidiar con los valores faltantes.

# %%
import pandas as pd
import numpy as np

datos = pd.read_csv("../nhanes_2015_2016.csv")

# Semilla

np.random.seed(0)

# %% [markdown]
# Lo primero que debe hacer cuando obtiene un nuevo conjunto de datos es echar un vistazo a algunos de ellos. Esto le permite ver que todo se leyó correctamente y le da una idea de lo que está pasando con los datos. En este caso, veamos si faltan valores, que se representarán con NaN o Ninguno.

# %%
datos.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %% [markdown]
# Sí, parece que faltan algunos valores.
#
# ¿Cuántos puntos de datos faltantes tenemos?
# Bien, ahora sabemos que nos faltan algunos valores. Veamos cuántos tenemos en cada columna.

# %%
# obtener el número de puntos de datos faltantes por columna

faltantes = datos.isnull().sum()
faltantes
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
# también podemos definir el nuemro de columnas a mostrar

faltantes[0:10]
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# dtype: int64

# %% [markdown]
# ¡Eso parece mucho! Podría ser útil ver qué porcentaje de los valores en nuestro conjunto de datos faltaba para darnos una mejor idea de la escala de este problema:

# %%
#  shape cuenta el total de filas y columnas
celdas = np.product(datos.shape)
total_faltantes = faltantes.sum()

print(total_faltantes)
print(celdas)
# porcentaje de datos
# Out:
# 11659
# 160580

# %%
datos.shape
# Out:
# (5735, 28)

# %%
5735*28
# Out:
# 160580

# %%
# para hacer el porcentaje se divide para generar el promedio

porcentaje = (total_faltantes/celdas)*100
porcentaje
# Out:
# 7.2605554863619375

# %% [markdown]
# ¡Vaya,  casi el 7 %  de las celdas de este conjunto de datos están vacías! En el siguiente paso, vamos a echar un vistazo más de cerca a algunas de las columnas a las que les faltan valores e intentaremos averiguar qué podría estar pasando con ellas.

# %% [markdown]
# # Averiguar por qué faltan los datos
# Este es el punto en el que entramos en la parte de la ciencia de datos que me gusta llamar "intuición de datos", con lo que quiero decir "ver realmente sus datos y tratar de averiguar por qué es así y cómo se comportará". afectar su análisis". Puede ser una parte frustrante de la ciencia de datos, especialmente si eres nuevo en el campo y no tienes mucha experiencia. Para lidiar con valores faltantes, deberá usar su intuición para descubrir por qué falta el valor. Una de las preguntas más importantes que puede hacerse para ayudar a resolver esto es la siguiente:
#
# **¿Falta este valor porque no se registró o porque no existe?**
#
# Si falta un valor porque no existe (como la altura del hijo mayor de alguien que no tiene hijos), entonces no tiene sentido tratar de adivinar cuál podría ser. Es probable que desee mantener estos valores como NaN. Por otro lado, si falta un valor porque no se registró, puede intentar adivinar cuál podría haber sido en función de los otros valores en esa columna y fila. ¡Esto se llama imputación, y aprenderemos cómo hacerlo a continuación! :)
#
# Trabajemos con un ejemplo. Al observar la cantidad de valores faltantes en el marco de datos.

# %%
# mira las primeras columas de datos

faltantes[0:10]
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# dtype: int64

# %% [markdown]
# # Ejemplo
#
# Al mirar la documentación, puedo ver que esta columna tiene información sobre la cantidad de segundos que quedan en el juego cuando se realizó la jugada. Esto significa que estos valores probablemente falten porque no se registraron, y no porque no existan. Por lo tanto, tendría sentido que intentáramos adivinar cuáles deberían ser en lugar de dejarlos como NA.
#
# Por otro lado, hay otros campos, como "Equipo Penalizado" que también tienen muchos campos faltantes. En este caso, sin embargo, falta el campo porque si no hubo penalización entonces no tiene sentido decir qué equipo fue penalizado. Para esta columna, tendría más sentido dejarla vacía o agregar un tercer valor como "ninguno" y usarlo para reemplazar las NA.Al mirar la documentación, puedo ver que esta columna tiene información sobre la cantidad de segundos que quedan en el juego cuando se realizó la jugada. Esto significa que estos valores probablemente falten porque no se registraron, y no porque no existan. Por lo tanto, tendría sentido que intentáramos adivinar cuáles deberían ser en lugar de dejarlos como NA.
#
# Por otro lado, hay otros campos, como "Equipo Penalizado" que también tienen muchos campos faltantes. En este caso, sin embargo, falta el campo porque si no hubo penalización entonces no tiene sentido decir qué equipo fue penalizado. Para esta columna, tendría más sentido dejarla vacía o agregar un tercer valor como "ninguno" y usarlo para reemplazar las NA.
#
# >> Sugerencia: este es un excelente lugar para leer la documentación del conjunto de datos si aún no lo ha hecho. Si está trabajando con un conjunto de datos que obtuvo de otra persona, también puede intentar comunicarse con ellos para obtener más información.
#
# si está haciendo un análisis de datos muy cuidadoso, este es el punto en el que miraría cada columna individualmente para descubrir la mejor estrategia para completar esos valores faltantes. En el resto de este cuaderno, cubriremos algunas técnicas "rápidas y sucias" que pueden ayudarlo con los valores faltantes, pero probablemente también terminarán eliminando información útil o agregando algo de ruido a sus datos.
#
# # Eliminar valores faltantes
#
# Si tiene prisa o no tiene una razón para averiguar por qué faltan sus valores, una opción que tiene es simplemente eliminar las filas o columnas que contienen valores faltantes. **(Nota: por lo general, no recomiendo este enfoque para proyectos importantes. Por lo general, vale la pena tomarse el tiempo para revisar sus datos y mirar realmente todas las columnas con valores faltantes, una por una, para conocer realmente su conjunto de datos. .)**
#
# Si está seguro de que desea eliminar filas con valores faltantes, pandas tiene una función práctica, dropna(), para ayudarlo a hacerlo. ¡Probémoslo en nuestro conjunto de datos.

# %%
# removiendo todas las filas con datos vacios

datos.dropna()
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# 13    83754     2.0     1.0     1.0       2         2        67         2
# 27    83785     2.0     1.0     1.0       1         2        60         2
# 30    83788     2.0     1.0     1.0       1         2        69         3
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5609  93488     2.0     1.0     1.0       2         2        47         4
# 5632  93524     2.0     1.0     2.0       2         2        26         1
# 5647  93554     2.0     1.0     1.0       1         1        54         5
# 5702  93640     2.0     1.0     1.0       2         1        38         4
# 5714  93664     2.0     1.0     2.0       2         1        39         1
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %% [markdown]
# Esto puede eliminar todos nuestros datos si es que cada fila de nuestro conjunto le falta al menos un valor. De este modo de ocasionarse esto, se deberia tener en cuenta la eliminación todas las columnas que tienen al menos un valor faltante.

# %%
columnas_dropna = datos.dropna(axis=1)
print(columnas_dropna.head())
print(columnas_dropna.shape)
# Out:
#     SEQN  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  DMDHHSIZ   WTINT2YR  SDMVPSU  \
# 0  83732       1         1        62         3         2  134671.37        1
# 1  83733       1         1        53         3         1   24328.56        1
# 2  83734       1         1        78         3         2   12400.01        1
# 3  83735       2         2        56         3         1  102718.00        1
# 4  83736       2         2        42         4         5   17627.67        2
#
#    SDMVSTRA
# 0       125
# 1       125
# 2       131
# 3       131
# 4       126
# (5735, 9)

# %% [markdown]
# De 28 columnas pasamos a tener 9 columnas, lo cual no es lo más óptimo, especialmente porque muchos de nuestros datos son valiosos.

# %%
print("Columnas conjunto de datos: %d" %datos.shape[1])
print("Columnas con datos borrados %d" %columnas_dropna.shape[1])
# Out:
# Columnas conjunto de datos: 28
# Columnas con datos borrados 9

# %% [markdown]
# Hemos perdido bastantes datos, pero en este punto hemos eliminado con éxito todos los NaN de nuestros datos.
#
# # Rellenar los valores que faltan automáticamente
#
# Otra opción es tratar de completar los valores que faltan. Para lo siguiente, estoy obteniendo una pequeña subsección de los datos de la NFL para que se imprima bien.

# %%
sub_datos = datos.loc[:, "RIDAGEYR":"HIQ210"].head()
sub_datos
# Out:
#    RIDAGEYR  RIDRETH1  DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  \
# 0        62         3       1.0       5.0       1.0         2  134671.37
# 1        53         3       2.0       3.0       3.0         1   24328.56
# 2        78         3       1.0       3.0       1.0         2   12400.01
# 3        56         3       1.0       5.0       6.0         1  102718.00
# 4        42         4       1.0       4.0       3.0         5   17627.67
#
#    SDMVPSU  SDMVSTRA  INDFMPIR  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  \
# 0        1       125      4.39  ...   124.0    64.0   94.8  184.5    27.8
# 1        1       125      1.32  ...   140.0    88.0   90.4  171.4    30.8
# 2        1       131      1.51  ...   132.0    44.0   83.4  170.1    28.8
# 3        1       131      5.00  ...   134.0    68.0  109.8  160.9    42.4
# 4        2       126      1.23  ...   114.0    54.0   55.2  164.9    20.3
#
#    BMXLEG  BMXARML  BMXARMC  BMXWAIST  HIQ210
# ...

# %% [markdown]
# Podemos usar la función fillna() de Pandas para completar los valores faltantes en un marco de datos para nosotros. Una opción que tenemos es especificar con qué queremos que se reemplacen los valores de NaN. Aquí, estoy diciendo que me gustaría reemplazar todos los valores de NaN con 0.

# %%
sub_datos.fillna(0)
# Out:
#    RIDAGEYR  RIDRETH1  DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  \
# 0        62         3       1.0       5.0       1.0         2  134671.37
# 1        53         3       2.0       3.0       3.0         1   24328.56
# 2        78         3       1.0       3.0       1.0         2   12400.01
# 3        56         3       1.0       5.0       6.0         1  102718.00
# 4        42         4       1.0       4.0       3.0         5   17627.67
#
#    SDMVPSU  SDMVSTRA  INDFMPIR  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  \
# 0        1       125      4.39  ...   124.0    64.0   94.8  184.5    27.8
# 1        1       125      1.32  ...   140.0    88.0   90.4  171.4    30.8
# 2        1       131      1.51  ...   132.0    44.0   83.4  170.1    28.8
# 3        1       131      5.00  ...   134.0    68.0  109.8  160.9    42.4
# 4        2       126      1.23  ...   114.0    54.0   55.2  164.9    20.3
#
#    BMXLEG  BMXARML  BMXARMC  BMXWAIST  HIQ210
# ...

# %% [markdown]
# Esto debe se rcuidadoso porque podría afectar el tipo de datos que tenemos, entonces es importante conocer bien el conjunto de información.

# %% [markdown]
# También podría ser un poco más inteligente y reemplazar los valores faltantes con cualquier valor que venga directamente después en la misma columna. (Esto tiene mucho sentido para conjuntos de datos donde las observaciones tienen algún tipo de orden lógico).

# %%
print(sub_datos.fillna(method="bfill",axis=0)) # este remplaza los valores por observaciones de la misma columna
print("--"*9)
print(sub_datos.fillna(method="bfill",axis=0).fillna(0)) # este hace lo mismo que el de arriba y los faltantes los guarda con 0

# axis serán filas
# Out:
#    RIDAGEYR  RIDRETH1  DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  \
# 0        62         3       1.0       5.0       1.0         2  134671.37
# 1        53         3       2.0       3.0       3.0         1   24328.56
# 2        78         3       1.0       3.0       1.0         2   12400.01
# 3        56         3       1.0       5.0       6.0         1  102718.00
# 4        42         4       1.0       4.0       3.0         5   17627.67
#
#    SDMVPSU  SDMVSTRA  INDFMPIR  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  \
# 0        1       125      4.39  ...   124.0    64.0   94.8  184.5    27.8
# 1        1       125      1.32  ...   140.0    88.0   90.4  171.4    30.8
# 2        1       131      1.51  ...   132.0    44.0   83.4  170.1    28.8
# 3        1       131      5.00  ...   134.0    68.0  109.8  160.9    42.4
# 4        2       126      1.23  ...   114.0    54.0   55.2  164.9    20.3
#
#    BMXLEG  BMXARML  BMXARMC  BMXWAIST  HIQ210
# ...

# %% [markdown]
# **En esta libreta, vamos a ver cómo escalar y normalizar datos (¡y cuál es la diferencia entre los dos!).**
#
# ¡Empecemos!**

# %% [markdown]
# Configura nuestro entorno
# Lo primero que tendremos que hacer es cargar las bibliotecas que usaremos.

# %%
import pandas as pd
import numpy as np

from scipy import stats

from mlxtend.preprocessing import minmax_scaling

import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)

# %%
datos = pd.read_csv("../nhanes_2015_2016.csv")

# %% [markdown]
# # Escalado vs. Normalización:
# ¿Cuál es la diferencia?
# Una de las razones por las que es fácil confundirse entre escalado y normalización es que los términos a veces se usan indistintamente y, para hacerlo aún más confuso, ¡son muy similares! En ambos casos, está transformando los valores de las variables numéricas para que los puntos de datos transformados tengan propiedades útiles  específicas. La diferencia es que: al escalar, está cambiando el rango de sus datos, mientras que en la normalización, está cambiando la forma de la distribución de sus datos.
# Vamos a hablar un poco más en profundidad sobre cada una de estas opciones.
#
# # Escalada
# Esto significa que está transformando sus datos para que se ajusten a una escala específica, como 0-100 o 0-1. Desea escalar los datos cuando utiliza métodos basados en medidas de la distancia entre los puntos de datos, como las máquinas de vectores de soporte (SVM) o los k-vecinos más cercanos (KNN). Con estos algoritmos, se le da la misma importancia a un cambio de "1" en cualquier característica numérica.
#
# Por ejemplo, es posible que esté viendo los precios de algunos productos tanto en yenes como en dólares estadounidenses. Un dólar estadounidense vale aproximadamente 100 yenes, pero si no escala sus precios, métodos como SVM o KNN considerarán una diferencia de precio de 1 yen tan importante como una diferencia de 1 dólar estadounidense. Esto claramente no encaja con nuestras intuiciones del mundo. Con la moneda, puede convertir entre monedas. Pero, ¿qué pasa si estás mirando algo como la altura y el peso? No está del todo claro cuántas libras deberían equivaler a una pulgada (o cuántos kilogramos deberían equivaler a un metro).
#
# Al escalar sus variables, puede ayudar a comparar diferentes variables en igualdad de condiciones. Para ayudar a solidificar cómo se ve la escala, veamos un ejemplo inventado.

# %%
# generar 1000 puntos de datos extraídos aleatoriamente de una distribución exponencial

puntos_datos = np.random.exponential(size=1000)

# min_max 

escala_datos = minmax_scaling(puntos_datos, columns=[0])


# graficos para comparar

fig, ax = plt.subplots(1,2, figsize=(15,3))
sns.histplot(puntos_datos, ax=ax[0],kde=True, legend=False)
ax[0].set_title("Datos Originales")
sns.histplot(escala_datos, ax=ax[1],kde=True, legend=False)
ax[1].set_title("Datos Escalados")

plt.show()

# %% [markdown]
# Observe que la forma de los datos no cambia, pero en lugar de variar de 0 a 8, ahora varía de 0 a 1.
#
# # Normalización
# Escalar solo cambia el rango de sus datos. La normalización es una transformación más radical. El objetivo de la normalización es cambiar sus observaciones para que puedan describirse como una distribución normal.
#
# Distribución normal: también conocida como "curva de campana", se trata de una distribución estadística específica en la que aproximadamente las mismas observaciones caen por encima y por debajo de la media, la media y la mediana son iguales y hay más observaciones más cercanas a la media. La distribución normal también se conoce como distribución gaussiana.
#
# En general, normalizará sus datos si va a utilizar una técnica estadística o de aprendizaje automático que suponga que sus datos se distribuyen normalmente. Algunos ejemplos de estos incluyen el análisis discriminante lineal (LDA) y el bayesiano ingenuo gaussiano. (Consejo profesional: cualquier método con "Gaussian" en el nombre probablemente asuma la normalidad).
#
# El método que estamos usando para normalizar aquí se llama Transformación de Box-Cox. Echemos un vistazo rápido a cómo se ve la normalización de algunos datos:

# %%
# normalizar los datos exponenciales con boxcox

datos_normalizados = stats.boxcox(puntos_datos)

# graficos

fig, ax = plt.subplots(1,2, figsize=(15,3))
sns.histplot(puntos_datos, ax=ax[0],kde=True, legend=False)
ax[0].set_title("Datos Originales")
sns.histplot(datos_normalizados, ax=ax[1],kde=True, legend=False)
ax[1].set_title("Datos Normalizados")

plt.show()

# %% [markdown]
# Observe que la forma de nuestros datos ha cambiado. Antes de normalizarse tenía casi forma de L. Pero después de normalizar se parece más al contorno de una campana (de ahí la "curva de campana").

# %%
# modules we'll use
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# read in our data
datos = pd.read_csv("../Reporte_Delito_Violencia_Intrafamiliar_Polic_a_Nacional.csv",engine='python')

# set seed for reproducibility
np.random.seed(0)

# %%
datos.head()
# Out:
#    DEPARTAMENTO          MUNICIPIO CODIGO DANE                 ARMAS MEDIOS  \
# 0     ATLÁNTICO  BARRANQUILLA (CT)     8001000  ARMA BLANCA / CORTOPUNZANTE
# 1        BOYACÁ            DUITAMA    15238000  ARMA BLANCA / CORTOPUNZANTE
# 2       CAQUETÁ        PUERTO RICO    18592000  ARMA BLANCA / CORTOPUNZANTE
# 3      CASANARE               MANÍ    85139000  ARMA BLANCA / CORTOPUNZANTE
# 4  CUNDINAMARCA   BOGOTÁ D.C. (CT)    11001000  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO GRUPO ETARIO  CANTIDAD
# 0   1/01/2010  MASCULINO      ADULTOS         1
# 1   1/01/2010   FEMENINO      ADULTOS         1
# 2   1/01/2010  MASCULINO      ADULTOS         1
# 3   1/01/2010   FEMENINO      ADULTOS         1
# 4   1/01/2010   FEMENINO      ADULTOS         1

# %%
print(datos["FECHA HECHO"].tail(30))
# Out:
# 476940    28/02/2021
# 476941     8/03/2021
# 476942    13/03/2021
# 476943    17/03/2021
# 476944    23/03/2021
# 476945    25/03/2021
# 476946    11/04/2021
# 476947    11/04/2021
# 476948    25/04/2021
# 476949     1/05/2021
# 476950     2/05/2021
# 476951     9/05/2021
# 476952    15/05/2021
# 476953    16/05/2021
# 476954    30/05/2021
# 476955    23/05/2021
# 476956    21/02/2021
# 476957     5/01/2021
# 476958    14/01/2021
# 476959    26/03/2021
# 476960    27/03/2021
# 476961    15/04/2021
# 476962         44335
# 476963         44335
# 476964         44199
# 476965         44250
# 476966         44262
# 476967         44300
# 476968         44294
# 476969         44245
# Name: FECHA HECHO, dtype: object

# %% [markdown]
# Sí, ¡son fechas! Pero sólo porque yo, un humano, pueda decir que son fechas no significa que Python sepa que son fechas. Fíjate que en la parte inferior de la salida de head(), puedes ver que dice que el tipo de datos de esta columna es "object".
#
# Pandas usa el dtype "object" para almacenar varios tipos de datos, pero lo más habitual es que cuando veas una columna con el dtype "object" contenga cadenas.
#
# Si revisas la documentación de dtype de pandas aquí, te darás cuenta de que también hay un dtypes específico datetime64. Como el dtype de nuestra columna es object y no datetime64, podemos decir que Python no sabe que esta columna contiene fechas.
#
# También podemos ver sólo el dtype de una columna sin imprimir las primeras filas:

# %%
datos["FECHA HECHO"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Puede que tengas que consultar la documentación de numpy para hacer coincidir el código de la letra con el dtype del objeto. "O" es el código de "objeto", por lo que podemos ver que estos dos métodos nos dan la misma información.

# %% [markdown]
# Convertir nuestras columnas FECHA HECHO a datetime
# Ahora que sabemos que nuestra columna de fecha no está siendo reconocida como una fecha, es hora de convertirla para que sea reconocida como una fecha. Esto se llama "analizar fechas" porque estamos tomando una cadena e identificando las partes que la componen.
#
# Podemos determinar cuál es el formato de nuestras fechas con una guía llamada "directiva strftime", de la que puedes encontrar más información en este enlace. La idea básica es que hay que señalar qué partes de la fecha están dónde y qué signos de puntuación hay entre ellas. Hay muchas partes posibles de una fecha, pero las más comunes son %d para el día, %m para el mes, %y para un año de dos dígitos y %Y para un año de cuatro dígitos.
#
# Algunos ejemplos:
#
# 17-1-2007 tiene el formato "%m/%d/%y".
# 17-1-2007 tiene el formato "%d-%m-%Y".
# Si volvemos a mirar la cabecera de la columna "date" (fecha) en el conjunto de datos de desprendimientos, vemos que tiene el formato "month/day/two-digit year" (mes/día/año de dos dígitos), por lo que podemos utilizar la misma sintaxis que en el primer ejemplo para analizar las fechas:

# %%
# En datos la columna 4 o la columnas FECHA HECHO tenia faltando 8 datos en el df.
# Hice una lista y rango y remplace ese dato con 1990

# %%
lista = [-1,-2,-3,-4,-5,-6,-7,-8]

for i in range(8):
    
    print(lista[i],"si")
    datos.iloc[lista[i],4] = "01/01/1900" 


datos["FECHA HECHO"].tail(12)
# Out:
# -1 si
# -2 si
# -3 si
# -4 si
# -5 si
# -6 si
# -7 si
# -8 si
# 476958    14/01/2021
# 476959    26/03/2021
# 476960    27/03/2021
# 476961    15/04/2021
# 476962    01/01/1900
# 476963    01/01/1900
# 476964    01/01/1900
# 476965    01/01/1900
# 476966    01/01/1900
# 476967    01/01/1900
# 476968    01/01/1900
# 476969    01/01/1900
# Name: FECHA HECHO, dtype: object

# %%
datos["FECHA_ARREGLADA"]= pd.to_datetime(datos["FECHA HECHO"], format="%d/%m/%Y")

# %%
datos.FECHA_ARREGLADA # Cambio el dato a datetime64
# Out:
# 0        2010-01-01
# 1        2010-01-01
# 2        2010-01-01
# 3        2010-01-01
# 4        2010-01-01
#             ...
# 476965   1900-01-01
# 476966   1900-01-01
# 476967   1900-01-01
# 476968   1900-01-01
# 476969   1900-01-01
# Name: FECHA_ARREGLADA, Length: 476970, dtype: datetime64[ns]

# %% [markdown]
# Ahora que nuestras fechas se analizan correctamente, podemos interactuar con ellas de forma útil.
#
# ¿Qué pasa si me encuentro con un error con múltiples formatos de fecha? Mientras estamos especificando el formato de fecha aquí, a veces nos encontraremos con un error cuando hay múltiples formatos de fecha en una sola columna. Si eso ocurre, puede hacer que pandas intente deducir cuál debe ser el formato de fecha correcto. Puede hacerlo así
#
# > landslides['date_parsed'] = pd.to_datetime(landslides['Date'], infer_datetime_format=True)
#
# ¿Por qué no utilizar siempre infer_datetime_format = True? Hay dos grandes razones para no hacer que pandas adivine siempre el formato de hora. La primera es que los pandas no siempre serán capaces de averiguar el formato de fecha correcto, especialmente si alguien se ha puesto creativo con la entrada de datos. La segunda es que es mucho más lento que especificar el formato exacto de las fechas.
#
#
# **Seleccionar el día del mes Ahora que tenemos una columna de fechas analizadas, podemos extraer información como el día del mes en que se produjo un desprendimiento.**

# %%
dia_del_mes = datos["FECHA_ARREGLADA"].dt.day
dia_del_mes.tail(15)
# Out:
# 476955    23
# 476956    21
# 476957     5
# 476958    14
# 476959    26
# 476960    27
# 476961    15
# 476962     1
# 476963     1
# 476964     1
# 476965     1
# 476966     1
# 476967     1
# 476968     1
# 476969     1
# Name: FECHA_ARREGLADA, dtype: int64

# %% [markdown]
# Si intentáramos obtener la misma información de la columna "fecha" original, obtendríamos un error: AttributeError: Sólo se puede utilizar el accesorio .dt con valores del tipo datetimelike. Esto se debe a que dt.day no sabe cómo tratar una columna con el dtype "object". Aunque nuestro marco de datos contiene fechas, tenemos que analizarlas antes de poder interactuar con ellas de forma útil.

# %% [markdown]
# # Trazar el día del mes para comprobar el análisis sintáctico de la fecha.
#
# Uno de los mayores peligros al analizar fechas es confundir los meses y los días. La función to_datetime() tiene mensajes de error muy útiles, pero no está de más volver a comprobar que los días del mes que hemos extraído tienen sentido.
#
# Para ello, vamos a trazar un histograma de los días del mes. Esperamos que tenga valores entre 1 y 31 y, puesto que no hay razón para suponer que los desprendimientos son más frecuentes en unos días del mes que en otros, una distribución relativamente uniforme. (Veamos si es así:

# %%
dias_del_mes_datos = dia_del_mes.dropna() # eliminamos espacios vacios

# plots

sns.distplot(dias_del_mes_datos, kde=False,bins=31)
# Out:
# /home/oscar/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='FECHA_ARREGLADA'>

# %% [markdown]
# Sí, parece que hemos analizado las fechas correctamente y este gráfico tiene sentido para mí.

# %%
"""
date_lengths = datos["FECHA HECHO"].str.len()
date_lengths.value_counts()

Cuenta por cuantos elementos esta compuesta una fecha cuando esta en formato str
"""
# Out:
# '\ndate_lengths = datos["FECHA HECHO"].str.len()\ndate_lengths.value_counts()\n\nCuenta por cuantos elementos esta compuesta una fecha cuando esta en formato str\n'

# %%
"""
INDICES CORRUPTOS - Son elementos que tienen más datos de los normal en el str

indices = np.where([date_lengths == 24])[1]
print('Indices with corrupted data:', indices)
earthquakes.loc[indices]


"""
# Out:
# "\nINDICES CORRUPTOS - Son elementos que tienen más datos de los normal en el str\n\nindices = np.where([date_lengths == 24])[1]\nprint('Indices with corrupted data:', indices)\nearthquakes.loc[indices]\n\n\n"

# %% [markdown]
# ¿Qué son las codificaciones?
# Las codificaciones de caracteres son conjuntos específicos de reglas para el mapeo de cadenas de bytes binarios sin procesar (que se ven así: 0110100001101001) a caracteres que forman texto legible por humanos (como "hola"). Hay muchas codificaciones diferentes, y si intentó leer un texto con una codificación diferente a la que estaba escrita originalmente, terminó con un texto codificado llamado "mojibake" (dicho como mo-gee-bah-kay). Aquí hay un ejemplo de mojibake:
#
# æ–‡å—åŒ–ã??
#
# También puede terminar con caracteres "desconocidos". Hay lo que se imprime cuando no hay una asignación entre un byte en particular y un carácter en la codificación que está usando para leer su cadena de bytes y se ven así:
#
#           ????????
#
# Las discrepancias en la codificación de caracteres son menos comunes hoy en día de lo que solían ser, pero definitivamente sigue siendo un problema. Hay muchas codificaciones de caracteres diferentes, pero la principal que debe conocer es UTF-8.
#
# UTF-8 es la codificación de texto estándar. Todo el código de Python está en UTF-8 e, idealmente, todos sus datos también deberían estarlo. Es cuando las cosas no están en UTF-8 cuando te encuentras con problemas.
#
# Fue bastante difícil lidiar con las codificaciones en Python 2, pero afortunadamente en Python 3 es mucho más simple. (Kaggle Notebooks solo usa Python 3). Hay dos tipos de datos principales que encontrará cuando trabaje con texto en Python 3. Uno es la cadena, que es el texto predeterminado.

# %%
before = "este es un sumbolo de euro €"

type(before)
# Out:
# str

# %% [markdown]
# Los otros datos son el tipo de datos de bytes, que es una secuencia de números enteros. Puede convertir una cadena en bytes especificando en qué codificación se encuentra:

# %%
after = before.encode("utf-8", errors="replace")

type(after)
# Out:
# bytes

# %% [markdown]
# Si observa un objeto de bytes, verá que tiene una b delante de él, y luego tal vez algo de texto después. Eso es porque los bytes se imprimen como si fueran caracteres codificados en ASCII. (ASCII es una codificación de caracteres más antigua que en realidad no funciona para escribir en ningún otro idioma que no sea el inglés). Aquí puede ver que nuestro símbolo del euro ha sido reemplazado por un mojibake que parece "\xe2\x82\xac" cuando está impreso. como si fuera una cadena ASCII.

# %%
after
# Out:
# b'este es un sumbolo de euro \xe2\x82\xac'

# %% [markdown]
# Cuando volvemos a convertir nuestros bytes en una cadena con la codificación correcta, podemos ver que todo nuestro texto está allí correctamente, ¡lo cual es genial! :)

# %%
print(after.decode("utf-8"))
# Out:
# este es un sumbolo de euro €

# %% [markdown]
# Sin embargo, cuando intentamos usar una codificación diferente para mapear nuestros bytes en una cadena, obtenemos un error. Esto se debe a que la codificación que intentamos usar no sabe qué hacer con los bytes que intentamos pasar. Debe decirle a Python la codificación en la que se supone que está la cadena de bytes.
#
# > Puede pensar en diferentes codificaciones como diferentes formas de grabar música. Puede grabar la misma música en un CD, cinta de casete o de 8 pistas. Si bien la música puede sonar más o menos igual, debe usar el equipo adecuado para reproducir la música de cada formato de grabación. El decodificador correcto es como un reproductor de casetes o un reproductor de CD. Si intenta reproducir un casete en un reproductor de CD, simplemente no funcionará

# %%
print(after.decode("ascii")) # debe dar error
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_25778/938697088.py in <module>
# ----> 1 print(after.decode("ascii"))
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 27: ordinal not in range(128)

# %% [markdown]
# También podemos tener problemas si intentamos usar la codificación incorrecta para asignar una cadena a bytes. Como dije antes, las cadenas son UTF-8 de forma predeterminada en Python 3, por lo que si tratamos de tratarlas como si estuvieran en otra codificación, crearemos problemas.
#
# Por ejemplo, si tratamos de convertir una cadena a bytes para ASCII usando encode(), podemos pedir que los bytes sean lo que serían si el texto estuviera en ASCII. Sin embargo, dado que nuestro texto no está en ASCII, habrá algunos caracteres que no podrá manejar. Podemos reemplazar automáticamente los caracteres que ASCII no puede manejar. Sin embargo, si hacemos eso, cualquier carácter que no esté en ASCII será reemplazado por el carácter desconocido. Luego, cuando volvamos a convertir los bytes en una cadena, el carácter se reemplazará con el carácter desconocido. La parte peligrosa de esto es que no hay forma de saber qué personaje debería haber sido. ¡Eso significa que es posible que hayamos inutilizado nuestros datos!

# %%
before = "This is the euro symbol: €"

# codificarlo a una codificación diferente, reemplazando los caracteres que generan errores
after = before.encode("ascii",errors="replace")

#convertir a utf-8

print(after.decode("ascii"))
# Out:
# This is the euro symbol: ?

# %% [markdown]
# ¡Esto es malo y queremos evitar hacerlo! Es mucho mejor convertir todo nuestro texto a UTF-8 tan pronto como podamos y mantenerlo en esa codificación. El mejor momento para convertir una entrada que no sea UTF-8 en UTF-8 es cuando lee archivos, de lo que hablaremos a continuación.
#
# # Lectura en archivos con problemas de codificación
# La mayoría de los archivos que encontrará probablemente estarán codificados con UTF-8. Esto es lo que Python espera de forma predeterminada, por lo que la mayoría de las veces no tendrá problemas. Sin embargo, a veces obtendrá un error como este:
#
# ¡Observe que obtenemos el mismo UnicodeDecodeError que obtuvimos cuando intentamos decodificar bytes UTF-8 como si fueran ASCII! Esto nos dice que este archivo no es en realidad UTF-8. Sin embargo, no sabemos qué codificación es en realidad. Una forma de resolverlo es probar y probar un montón de codificaciones de caracteres diferentes y ver si alguno de ellos funciona. Sin embargo, una mejor manera es usar el módulo charset_normalizer para tratar de adivinar automáticamente cuál es la codificación correcta. No está 100% garantizado que sea correcto, pero generalmente es más rápido que solo tratar de adivinar.

# %%
"""
with open("../input/kickstarter-projects/ks-projects-201801.csv", 'rb') as rawdata:
    result = charset_normalizer.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)

out:

{'encoding': 'utf-8', 'language': 'English', 'confidence': 1.0}
"""
# Out:
# '\nwith open("../input/kickstarter-projects/ks-projects-201801.csv", \'rb\') as rawdata:\n    result = charset_normalizer.detect(rawdata.read(10000))\n\n# check what the character encoding might be\nprint(result)\n\nout:\n\n{\'encoding\': \'utf-8\', \'language\': \'English\', \'confidence\': 1.0}\n'

# %% [markdown]
# ¡Sí, parece que charset_normalizer tenía razón! El archivo se lee sin problemas (aunque recibimos una advertencia sobre los tipos de datos) y cuando miramos las primeras filas parece estar bien.
#
# ¿Qué pasa si la codificación charset_normalizer adivina no es correcta? Dado que charset_normalizer es básicamente un adivinador elegante, a veces adivinará la codificación incorrecta. Una cosa que puede intentar es mirar más o menos parte del archivo y ver si obtiene un resultado diferente y luego intentarlo.

# %% [markdown]
# # Limpiando Datos
#
# Limpiar datos en grupo de una manera eficiente.

# %%
# modules we'll use
import pandas as pd
import numpy as np

# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import charset_normalizer

# read in all our data
salud = pd.read_csv("../nhanes_2015_2016.csv")

# set seed for reproducibility
np.random.seed(0)

# %%
salud.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
educativo = salud.DMDEDUC2.unique()

educativo.sort()
educativo
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  9., nan])

# %% [markdown]
# Solo mirando esto, puedo ver algunos problemas debido a la entrada de datos inconsistentes: 'Alemania' y 'alemania', por ejemplo, o 'Nueva Zelanda' y 'Nueva Zelanda'.
#
# Lo primero que voy a hacer es poner todo en minúsculas (puedo volver a cambiarlo al final si quiero) y eliminar los espacios en blanco al principio y al final de las celdas. Las inconsistencias en las mayúsculas y los espacios en blanco finales son muy comunes en los datos de texto y puede corregir un buen 80 % de las inconsistencias en la entrada de datos de texto haciendo esto.
#
# EN NUESTRO CASO, NO ESTOS PROBLEMAS PERO ES BUENO SABER QUE POR EJEMPOLO HAYAN PROBLEMAS de minusculas o mayusculas.

# %%
"""
primero pasamos todo a minusculas

datos["a"] = datos["a"].str.lower()


# eliminar los espacios en blanco finales

datos["a"] = datos["a"].str.strip()

"""
# Out:
# '\nprimero pasamos todo a minusculas\n\ndatos["a"] = datos["a"].str.lower()\n\n\n# eliminar los espacios en blanco finales\n\ndatos["a"] = datos["a"].str.strip()\n\n'

# %% [markdown]
# A continuación, abordaremos las incoherencias más difíciles.
#
# Use la coincidencia aproximada para corregir la entrada de datos inconsistentes
# Muy bien, echemos otro vistazo a la columna "País" y veamos si hay más limpieza de datos que debamos hacer.

# %%
educativo = salud.DMDEDUC2.unique()

educativo.sort()
educativo
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  9., nan])

# %% [markdown]
# Parece que hay otra incoherencia: 'southkorea' and 'south korea'  deberían ser lo mismo.
#
# Vamos a usar el paquete fuzzywuzzy para ayudar a identificar qué cadenas están más cerca unas de otras. Este conjunto de datos es lo suficientemente pequeño como para que probablemente podamos corregir los errores a mano, pero ese enfoque no escala bien. (¿Le gustaría corregir mil errores a mano? ¿Qué tal diez mil? Por lo general, automatizar las cosas lo antes posible es una buena idea. Además, ¡es divertido!)
#
# Coincidencia aproximada: El proceso de encontrar automáticamente cadenas de texto que son muy similares a la cadena de destino. En general, una cadena se considera "más cercana" a otra cuantos menos caracteres necesite cambiar si estuviera transformando una cadena en otra. Entonces, "apple" y "snapple" están a dos cambios de distancia (agregue "s" y "n") mientras que "in" y "on" y un cambio de distancia (reemplace "i" con "o"). No siempre podrá confiar en la coincidencia aproximada al 100%, pero por lo general terminará ahorrándole al menos un poco de tiempo.
#
# >Fuzzywuzzy devuelve una proporción dadas dos cadenas. Cuanto más cerca esté la proporción de 100, menor será la distancia de edición entre las dos cadenas. Aquí, vamos a obtener las diez cuerdas de nuestra lista de ciudades que tienen la distancia más cercana a "corea del sur".

# %%
"""
coincidencias = fuzzywuzzy.process.extract("south korea", countries, limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

# imprime las coincidencias

coincidencias

"""
# Out:
# '\ncoincidencias = fuzzywuzzy.process.extract("south korea", countries, limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)\n\n# imprime las coincidencias\n\ncoincidencias\n\n'

# %% [markdown]
# Podemos ver que dos de los elementos de las ciudades están muy cerca de "south korea": "south korea" and "southkorea". Reemplacemos todas las filas en nuestra columna "País" que tienen una proporción de > 47 con "Corea del Sur".
#
# Para hacer esto, voy a escribir una función. (Es una buena idea escribir una función de propósito general que pueda reutilizar si cree que podría tener que hacer una tarea específica más de una o dos veces. Esto evita que tenga que copiar y pegar el código con demasiada frecuencia, lo que ahorra tiempo y puede ayudar evitar errores).
#
# out:
#
# [('south korea', 100),
#  ('southkorea', 48),
#  ('saudi arabia', 43),
#  ('norway', 35),
#  ('austria', 33),
#  ('ireland', 33),
#  ('pakistan', 32),
#  ('portugal', 32),
#  ('scotland', 32),
#  ('australia', 30)]

# %%
"""
def remplazar(df, columna, string_coincidencia, min_ratio = 47):
    # obtine los datos unicos
    strings = df[columna].unique()
    
    # obtener las 10 coincidencias más cercanas a nuestra cadena de entrada
    
    coincidencia = fuzzywuzzy.process.extract(
                    string_coincidencia, strings,
                    limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio
                    
    # solo obtener coincidencias con una proporción> 90
    
    concidencia_cerrada = [coincidencia[0] for coincidencia in coincidencia if coincidencia[1]>= min_ratio]
    
    # obtener las filas de todas las coincidencias cercanas en nuestro marco de datos
    
    fila_coincidencia = df[columna].isin(coincidencia_cerrada)
    
    # reemplazar todas las filas con coincidencias cercanas con las coincidencias de entrada

    df.loc[fila_coincidencia, columna] = string_coincidencia
    
    print("All done")
    
    )
    


"""
# Out:
# '\ndef remplazar(df, columna, string_coincidencia, min_ratio = 47):\n    # obtine los datos unicos\n    strings = df[columna].unique()\n    \n    # obtener las 10 coincidencias más cercanas a nuestra cadena de entrada\n    \n    coincidencia = fuzzywuzzy.process.extract(\n                    string_coincidencia, strings,\n                    limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio\n                    \n    # solo obtener coincidencias con una proporción> 90\n    \n    concidencia_cerrada = [coincidencia[0] for coincidencia in coincidencia if coincidencia[1]>= min_ratio]\n    \n    # obtener las filas de todas las coincidencias cercanas en nuestro marco de datos\n    \n    fila_coincidencia = df[columna].isin(coincidencia_cerrada)\n    \n    # reemplazar todas las filas con coincidencias cercanas con las coincidencias de entrada\n\n    df.loc[fila_coincidencia, columna] = string_coincidencia\n    \n    print("All done")\n    \n    )\n    \n\n\n'

# %%
# creado el objeto

#remplazar(df=salud, columna="pais",string_coincidencia="south korea")

# %% [markdown]
# Y ahora revisemos los valores únicos en nuestra columna "País" nuevamente y asegurémonos de haber ordenado "Corea del Sur" correctamente.
#
#
#
# >countries = professors['Country'].unique()
# countries.sort()
# countries
